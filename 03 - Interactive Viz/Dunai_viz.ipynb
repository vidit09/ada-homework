# %% [markdown]
# # Interactive Visualisation

# %%
import numpy as np
import pandas as pd
import folium
import json
from urllib.request import urlopen
from urllib import parse
import requests

# %%
df = pd.read_csv('P3_GrantExport.csv',sep=';')

# Transformation from string to floats in 'Approved Amount'
float_amounts = list()
for x in df['Approved Amount'].tolist():
    try:
        float_amounts.append(float(x))
    except:
        float_amounts.append(0) #When we are missing a real number we set the amount to 0 (basically to discard it later)
    
df = df[['University']] #we keep only university names associated at projects
df['Funding'] = float_amounts #and we attach float value of the Approved Amount, now renamed to 'Funding'
df.head()
# Out:
#                                 University   Funding
# 0                     Nicht zuteilbar - NA   11619.0
# 1                Université de Genève - GE   41022.0
# 2  NPO (Biblioth., Museen, Verwalt.) - NPO   79732.0
# 3                   Universität Basel - BS   52627.0
# 4  NPO (Biblioth., Museen, Verwalt.) - NPO  120042.0

# %%
df.count()
# Out:
# University    50988
# Funding       63969
# dtype: int64

# %%
sum(df['Funding'] == 0) #checking for projects without funding data.
# Out:
# 10997

# %%
df.University.describe()
# Out:
# count                       50988
# unique                         77
# top       Universität Zürich - ZH
# freq                         6774
# Name: University, dtype: object

# %%
funding_by_uni = df.groupby('University')[['Funding']].sum()
funding_by_uni['Longitude'] = ''; funding_by_uni['Latitude'] = ''; funding_by_uni['Canton'] = ''
funding_by_uni.head()
# Out:
#                                                        Funding Longitude  \
# University
# AO Research Institute - AORI                         3435621.0
# Allergie- und Asthmaforschung - SIAF                19169965.0
# Berner Fachhochschule - BFH                         31028695.0
# Biotechnologie Institut Thurgau - BITG               2492535.0
# Centre de rech. sur l'environnement alpin - CREALP   1567678.0
#
#                                                    Latitude Canton
# University
# AO Research Institute - AORI
# Allergie- und Asthmaforschung - SIAF
# Berner Fachhochschule - BFH
# Biotechnologie Institut Thurgau - BITG
# Centre de rech. sur l'environnement alpin - CREALP

# %%
funding_by_uni.describe()
# Out:
#             Funding
# count  7.700000e+01
# mean   1.685438e+08
# std    4.394375e+08
# min    8.000000e+03
# 25%    1.430686e+06
# 50%    6.882730e+06
# 75%    4.277191e+07
# max    1.838237e+09

# %% [markdown]
# 77 different universities with a huge disparity in funding. Maximum is 3 orders of magnitude bigger than the 1st quantile's top.

# %%
#imporving names before search
fbu = funding_by_uni.reset_index()

University_name = list()
University_code = list()
for x in fbu.University.tolist():

    try:
        name, code = x.split(' - ') #split by line
    except:
        name, code = x.split(' ') #or split by space
        
    University_name.append(name)
    University_code.append(code)
fbu['University_name'] = University_name
fbu['University_code'] = University_code
fbu.head()
# Out:
#                                           University     Funding Longitude  \
# 0                       AO Research Institute - AORI   3435621.0
# 1               Allergie- und Asthmaforschung - SIAF  19169965.0
# 2                        Berner Fachhochschule - BFH  31028695.0
# 3             Biotechnologie Institut Thurgau - BITG   2492535.0
# 4  Centre de rech. sur l'environnement alpin - CR...   1567678.0
#
#   Latitude Canton                            University_name University_code
# 0                                      AO Research Institute            AORI
# 1                              Allergie- und Asthmaforschung            SIAF
# 2                                      Berner Fachhochschule             BFH
# 3                            Biotechnologie Institut Thurgau            BITG
# 4                  Centre de rech. sur l'environnement alpin          CREALP

# %% [markdown]
# Using Geonames Full Text Search API to map the universities to their respective columns. 'requests' library is used to get the HTTP response. But since 'University' names have spaces and other special characters, it needs to be UTF-8 encoded before using the requests.get. This is accomplished using 'parse.quote' method in 'urllib' library.

# %%
num_projects = len(fbu)
username = 'dunaiada'

for i in range(0,num_projects):
    url = 'http://api.geonames.org/search?q=' + fbu['University_code'][i] + '&country=CH' + '&maxRows=1&username=' + username + '&type=json'
    ## Encode special characters and spaces
    query = parse.quote(url,safe=':/&=?')
    ## Parse JSON data
    # print(query)
        
    d = json.loads(requests.get(query).text)
    
    if bool(d['geonames']): #checks whether we get a match.
        try:
            fbu['Canton'].iloc[i] = d['geonames'][0]['adminCode1']
            fbu['Latitude'].iloc[i] = d['geonames'][0]['lat']
            fbu['Longitude'].iloc[i] = d['geonames'][0]['lng']
        except:
            pass
fbu.head()
# Out:
# http://api.geonames.org/search?q=AORI&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=SIAF&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=BFH&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=BITG&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=CREALP&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=EPFL&country=CH&maxRows=1&username=dunaiada&type=json
# C:\Users\dunay\Anaconda3\lib\site-packages\pandas\core\indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# http://api.geonames.org/search?q=ETHZ&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=EAWAG&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=WSL&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=EHB&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=EMPA&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=EOC&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=FHKD&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=FHNW&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=FHO&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=FTL&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=FFHS&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=FP&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=AGS&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=IRO&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=FIBL&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=SAGW&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=FUS&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=FMI&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=HES-SO&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=HEPBEJUNE&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=HEPL&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=HEPFR&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=HSLU&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=IDIAP&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=ISSKA&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=IHEID&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=IST&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=IUKB&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=IKG&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=IRSOL&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=HfH&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=ISR&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=KSPSG&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=NPO&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=NA&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=PSI&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=PMOD&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=ASP&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=PHBern&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=PHGR&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=PHLU&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=PHFHNW&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=PHSH&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=PHSZ&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=PHSG&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=PHTG&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=PHVS&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=PHZG&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=PHZFH&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=RWS&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=SUPSI&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=SHLR&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=SIK-ISEA&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=FORS&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=SPF&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=STHB&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=CSEM&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=SIB&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=USI&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=BS&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=BE&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=LU&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=SG&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=ZH&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=FR&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=GE&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=LA&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=NE&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=FINST&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=ASPIT&country=CH&maxRows=1&username=dunaiada&type=json
# http://api.geonames.org/search?q=ZFH&country=CH&maxRows=1&username=dunaiada&type=json
#                                           University     Funding Longitude  \
# 0                       AO Research Institute - AORI   3435621.0
# 1               Allergie- und Asthmaforschung - SIAF  19169965.0
# 2                        Berner Fachhochschule - BFH  31028695.0
# 3             Biotechnologie Institut Thurgau - BITG   2492535.0
# 4  Centre de rech. sur l'environnement alpin - CR...   1567678.0
#
#   Latitude Canton                            University_name University_code
# 0                                      AO Research Institute            AORI
# 1                              Allergie- und Asthmaforschung            SIAF
# 2                                      Berner Fachhochschule             BFH
# 3                            Biotechnologie Institut Thurgau            BITG
# 4                  Centre de rech. sur l'environnement alpin          CREALP

# %% [markdown]
# Currently considering only those universities which were mapped to their cantons.

# %%
## Removing all univerisites without canton mappings [TODO: To be changes]
fbu = fbu[fbu['Canton'] != '']
fbu
# Out:
#                                            University       Funding Longitude  \
# 5                                 EPF Lausanne - EPFL  1.175316e+09   6.56673
# 6                                   ETH Zürich - ETHZ  1.635597e+09   8.54805
# 7          Eidg. Anstalt für Wasserversorgung - EAWAG  7.461922e+07   8.61246
# 8   Eidg. Forschungsanstalt für Wald,Schnee,Land -...  4.836039e+07   8.45484
# 10          Eidg. Material und Prüfungsanstalt - EMPA  5.857452e+07   8.61246
# 13    Fachhochschule Nordwestschweiz (ohne PH) - FHNW  4.277191e+07   7.63856
# 38                   Kantonsspital St. Gallen - KSPSG  1.503410e+07   9.38826
# 40                               Nicht zuteilbar - NA  1.424257e+08   7.44744
# 41                       Paul Scherrer Institut - PSI  1.152690e+08   8.23028
# 43  Pädag. Hochschule Tessin (Teilschule SUPSI) - ASP  1.593170e+05   8.05034
# 56                SUP della Svizzera italiana - SUPSI  2.404008e+07   8.91741
# 60             Schweizer Paraplegiker Forschung - SPF  1.944211e+06   8.01723
# 65                             Universität Basel - BS  1.352251e+09   7.57327
# 66                              Universität Bern - BE  1.519373e+09   7.44744
# 67                            Universität Luzern - LU  3.998168e+07   8.30635
# 68                        Universität St. Gallen - SG  6.919495e+07   9.37477
# 69                            Universität Zürich - ZH  1.826843e+09      8.55
# 71                          Université de Genève - GE  1.838237e+09   6.14569
# 72                        Université de Lausanne - LA  1.183291e+09      8.55
# 73                       Université de Neuchâtel - NE  3.832046e+08     6.931
#
#     Latitude Canton                               University_name  \
# 5   46.51939     VD                                  EPF Lausanne
# 6    47.3763     ZH                                    ETH Zürich
# 7   47.40311     ZH            Eidg. Anstalt für Wasserversorgung
# 8   47.36044     ZH  Eidg. Forschungsanstalt für Wald,Schnee,Land
# 10  47.40311     ZH            Eidg. Material und Prüfungsanstalt
# 13  47.53378     BL      Fachhochschule Nordwestschweiz (ohne PH)
# 38  47.42925     SG                      Kantonsspital St. Gallen
# 40  46.94809     BE                               Nicht zuteilbar
# 41   47.5385     AG                        Paul Scherrer Institut
# 43  47.44496     AG   Pädag. Hochschule Tessin (Teilschule SUPSI)
# 56  46.02394     TI                   SUP della Svizzera italiana
# 60  46.95161     LU              Schweizer Paraplegiker Forschung
# 65  47.55839     BS                             Universität Basel
# 66  46.94809     BE                              Universität Bern
# 67  47.05048     LU                            Universität Luzern
# 68  47.42391     SG                        Universität St. Gallen
# 69  47.36667     ZH                            Universität Zürich
# 71  46.20222     GE                          Université de Genève
# 72  47.36667     ZH                        Université de Lausanne
# 73  46.99179     NE                       Université de Neuchâtel
#
#    University_code
# 5             EPFL
# 6             ETHZ
# 7            EAWAG
# 8              WSL
# 10            EMPA
# 13            FHNW
# 38           KSPSG
# 40              NA
# 41             PSI
# 43             ASP
# 56           SUPSI
# 60             SPF
# 65              BS
# 66              BE
# 67              LU
# 68              SG
# 69              ZH
# 71              GE
# 72              LA
# 73              NE

# %%
m = folium.Map(location=[46.76, 8.26], zoom_start=8, tiles='Mapbox Bright')
for i in range(len(fbu)):
    ## Add markers on all universities
    folium.Marker([fbu['Latitude'].iloc[i], fbu['Longitude'].iloc[i]], popup=fbu['University'].iloc[i],
                   icon = folium.Icon(icon = 'cloud')).add_to(m)
m.save('m.html') # Need to be seen in browser

# %%
#Now we do the grouping by canton
fbc = fbu.groupby('Canton')[['Funding']].sum()
fbc
# Out:
#              Funding
# Canton
# AG      1.154283e+08
# BE      1.661799e+09
# BL      4.277191e+07
# BS      1.352251e+09
# GE      1.838237e+09
# LU      4.192589e+07
# NE      3.832046e+08
# SG      8.422906e+07
# TI      2.404008e+07
# VD      1.175316e+09
# ZH      4.827284e+09

# %% [markdown]
# Plot the map using JSON file (with coordinates for each canton) and using the dataframe containing grant money for each canton.

# %%
geo_canton_data = json.load(open('ch-cantons.topojson.json'))
