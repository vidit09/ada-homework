# %% [markdown]
# ### OBJECTIVE
# To visualize the distribution of grants issued to different Swiss Cantons by Swiss National Science Foundation.

# %% [markdown]
# Import necessay libs

# %%
import pandas as pd
from urllib import parse
import json
import requests
import folium

# %% [markdown]
# Load the P3 database for Grants given to different Swiss Universities

# %%
data = pd.read_csv('P3_GrantExport.csv',sep=';')
data
# Out:
#        ﻿"Project Number"                                      Project Title  \
# 0                      1  Schlussband (Bd. VI) der Jacob Burckhardt-Biog...
# 1                      4  Batterie de tests à l'usage des enseignants po...
# 2                      5  Kritische Erstausgabe der "Evidentiae contra D...
# 3                      6  Katalog der datierten Handschriften in der Sch...
# 4                      7  Wissenschaftliche Mitarbeit am Thesaurus Lingu...
# 5                      8  Die schweizerische Wirtschaftspolitik seit dem...
# 6                      9  Theologische Forschungen zur Oekumene (Studien...
# 7                     10  Konfuzianische Kulturwerte in der sozialen Ent...
# 8                     11  Edizione degli scritti di Aurelio de' Giorgi B...
# 9                     13  La construction de nouveautés au sein des morp...
# 10                    14  Wissensstruktur, Fragegenese und Wissenserweit...
# 11                    17  Rechtsquellenkommission des Schweizerischen Ju...
# 12                    18  L'école et la vie: examens pédagogiques des re...
# 13                    19    Das Ringen um soziale Sicherheit in der Schweiz
# 14                    20  Kolloquium zum Thema "Ein System Sozialer Indi...
# 15                    21  Struktur und Funktion didaktischer Bezugssyste...
# 16                    23  Psycholinguistique génétique: l'évolution des ...
# 17                    25  Grösse, Verwaltungsstruktur und Entwicklung sc...
# 18                    26  Rollendifferenzierung bei Schweizer Ehepaaren ...
# 19                    27  Déviants sociaux et culturels, réseaux lausannois
# 20                    28  Evaluation de quelques objectifs d'une école e...
# 21                    30  Werte und Wertordnungen in der schweizerischen...
# 22                    32  Der Einfluss kleinstaatlicher Bedingungen auf ...
# 23                    33  Etude des instruments heuristiques propres à f...
# 24                    34  Die Haltung der Schweiz im Kalten Krieg (1945-...
# 25                    35  L'italiano regionale del canton Ticino.Ricerca...
# 26                    36          Aktion Bauernhausforschung in der Schweiz
# 27                    37  Erschliessung und Inventarisierung des Nachlas...
# 28                    38  Hateruma, sozio-religiöse Aspekte einer Inselk...
# 29                    39  Chronologie und Oekologie schweizerischer ur- ...
# ...                  ...                                                ...
# 63939             170414  Gleichstellungspolitik öffentlicher Arbeitgebe...
# 63940             170473  Johann Ferdinand Schor und seine Architekturma...
# 63941             170478  Cascading uncertainties in coupled component m...
# 63942             170510  Ist Addieren schwieriger als Multiplizieren in...
# 63943             170707     Halogenated Greenhouse Gases on a Global Scale
# 63944             170714  Modern Dance and Hollywood. A Transatlantic Ap...
# 63945             170715  Evolving bedrock erosion from modelled cosmoge...
# 63946             170716  The creation of a thick labor market between S...
# 63947             170718  Unraveling the mechanism of dendritic cell mat...
# 63948             170762  Effect of Material, Pore Size, and Configurati...
# 63949             170806  Spatial and temporal dynamics of N2O fluxes an...
# 63950             170812   Formes d'Europe : de l'Union européenne et d'...
# 63951             170813  NRP68 partial synthesis on spatial development...
# 63952             170814  Thematic Synthesis NRP68: Soil Data, Methods a...
# 63953             170815  Towards Sustainable Soil Policy - Thematic Syn...
# 63954             170817  Genomics of temperature tolerance in the ecolo...
# 63955             170883  Does Religion Make a Difference? Discourses an...
# 63956             170893  Cortical EEG- and MEG-sources of complex menta...
# 63957             170894  Towards the fetal connectome: developing diffu...
# 63958             170953  Conference "Human : Non-Human: Body, things, a...
# 63959             171009  Inventer la littérature médiévale (XVIe-XVIIe ...
# 63960             171100  Numerical and field study of Argentinian and N...
# 63961             171106  Anisotropic particles at fluid interfaces: the...
# 63962             171112  From the barricades into politics: the role of...
# 63963             171113                          La fin de l'intériorité ?
# 63964             171114                  Faulheit – Spielformen des Faulen
# 63965             171126               Sound Colour Space - Abschlusstagung
# 63966             171130  Combining Brain-Computer Interfaces and Neurom...
# 63967             171131  Computational optimization of a model-based in...
# 63968             171414  Growth Kinetics Interaction of Staphylococcus ...
#
#                                    Project Title English  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 63939  Equal Opportunity Policies of Public Employers...
# 63940  Johann Ferdinand Schor and his Architectural T...
# 63941  Cascading uncertainties in coupled component m...
# 63942  Is addying more difficult than multiplying in ...
# 63943     Halogenated Greenhouse Gases on a Global Scale
# 63944  Modern Dance and Hollywood. A Transatlantic Ap...
# 63945  Evolving bedrock erosion from modelled cosmoge...
# 63946  The creation of a thick labor market between S...
# 63947  Unraveling the mechanism of dendritic cell mat...
# 63948  Effect of Material, Pore Size, and Configurati...
# 63949  Spatial and temporal dynamics of N2O fluxes an...
# 63950  Forms of Europe : of the European Union and of...
# 63951  NRP68 partial synthesis on spatial development...
# 63952                                                NaN
# 63953                                                NaN
# 63954  Genomics of temperature tolerance in the ecolo...
# 63955  Does Religion Make a Difference? Discourses an...
# 63956  Cortical EEG- and MEG-sources of complex menta...
# 63957  Towards the fetal connectome: developing diffu...
# 63958                                                NaN
# 63959  Inventing medieval literature (16th-17th century)
# 63960  Numerical and field study of Argentinian and N...
# 63961  Anisotropic particles at fluid interfaces: the...
# 63962  From the barricades into politics: the role of...
# 63963                          La fin de l'intériorité ?
# 63964                                                NaN
# 63965              Sound Colour Space - Final Conference
# 63966  Combining Brain-Computer Interfaces and Neurom...
# 63967  Computational optimization of a model-based in...
# 63968  Growth Kinetics Interaction of Staphylococcus ...
#
#                                    Responsible Applicant  \
# 0                                           Kaegi Werner
# 1                                     Massarenti Léonard
# 2      Kommission für das Corpus philosophorum medii ...
# 3                                         Burckhardt Max
# 4                           Schweiz. Thesauruskommission
# 5                                    Kleinewefers Henner
# 6                                    Stirnimann Heinrich
# 7                                       Deuchler Martina
# 8                                        Stäuble Antonio
# 9                                            Piaget Jean
# 10                                        Flammer August
# 11     Schweizerische Rechtsquellen c/o Universität Z...
# 12                                           Girod Roger
# 13                                         Borner Silvio
# 14                         Hoffmann-Nowotny Hans-Joachim
# 15                                         Santini Bruno
# 16                                      Sinclair Hermina
# 17                                          Heintz Peter
# 18                                     Unteregger Judith
# 19                                       Willener Alfred
# 20                                      Huberman Michael
# 21                                          Rüegg Walter
# 22                                           Frei Daniel
# 23                                           Roulet Eddy
# 24                                         Bonjour Edgar
# 25                                       Bianconi Sandro
# 26            Schweizerische Gesellschaft für Volkskunde
# 27                         Kuratorium Carl J. Burckhardt
# 28                                    Ouwehand Cornelius
# 29                                       Bosshard Walter
# ...                                                  ...
# 63939                                       Fuchs Gesine
# 63940                                   Šterbová Daniela
# 63941                                Zischg Andreas Paul
# 63942                                     Ziegler Esther
# 63943                                  Vollmer Martin K.
# 63944                                    Köhler Kristina
# 63945                               Norton Kevin Patrick
# 63946                                     Beerli Andreas
# 63947                                   Kashyap Abhishek
# 63948                                         Howe Kerry
# 63949                                   Barthel Matthias
# 63950                                        Grin Gilles
# 63951                              Grêt-Regamey Adrienne
# 63952                                       Keller Armin
# 63953                                       Walter Felix
# 63954                                      Yampolsky Lev
# 63955                                   Köhrsen Jens-Ole
# 63956                                      Milz Patricia
# 63957                          Kuklisova Murgasova Maria
# 63958                                   Malinar Angelika
# 63959                                      Dahhaoui Yann
# 63960                                     Manzella Irene
# 63961                                      Senbil Nesrin
# 63962                                  Grano Simona Alba
# 63963                                   Pierron Nathalie
# 63964                                     Stetter Bitten
# 63965                                      Neukom Martin
# 63966                                 Millán José del R.
# 63967                             Szilágyi Sándor Miklós
# 63968                                        Frey Pascal
#
#                                  Funding Instrument  \
# 0                      Project funding (Div. I-III)
# 1                      Project funding (Div. I-III)
# 2                      Project funding (Div. I-III)
# 3                      Project funding (Div. I-III)
# 4                      Project funding (Div. I-III)
# 5                      Project funding (Div. I-III)
# 6                      Project funding (Div. I-III)
# 7                      Project funding (Div. I-III)
# 8                      Project funding (Div. I-III)
# 9                      Project funding (Div. I-III)
# 10                     Project funding (Div. I-III)
# 11                     Project funding (Div. I-III)
# 12                     Project funding (Div. I-III)
# 13                     Project funding (Div. I-III)
# 14                     Project funding (Div. I-III)
# 15                     Project funding (Div. I-III)
# 16                     Project funding (Div. I-III)
# 17                     Project funding (Div. I-III)
# 18                     Project funding (Div. I-III)
# 19                     Project funding (Div. I-III)
# 20                     Project funding (Div. I-III)
# 21                     Project funding (Div. I-III)
# 22                     Project funding (Div. I-III)
# 23                     Project funding (Div. I-III)
# 24                     Project funding (Div. I-III)
# 25                     Project funding (Div. I-III)
# 26                     Project funding (Div. I-III)
# 27                     Project funding (Div. I-III)
# 28                     Project funding (Div. I-III)
# 29                     Project funding (Div. I-III)
# ...                                             ...
# 63939                            Publication grants
# 63940           International short research visits
# 63941           International short research visits
# 63942           International short research visits
# 63943           International short research visits
# 63944           International short research visits
# 63945           International short research visits
# 63946           International short research visits
# 63947           International short research visits
# 63948           International short research visits
# 63949           International short research visits
# 63950                        Scientific Conferences
# 63951  NRP 68 Sustainable Use of Soil as a Resource
# 63952  NRP 68 Sustainable Use of Soil as a Resource
# 63953  NRP 68 Sustainable Use of Soil as a Resource
# 63954           International short research visits
# 63955           International Exploratory Workshops
# 63956           International short research visits
# 63957           International short research visits
# 63958                        Scientific Conferences
# 63959                        Scientific Conferences
# 63960           International short research visits
# 63961           International short research visits
# 63962           International short research visits
# 63963                        Scientific Conferences
# 63964                        Scientific Conferences
# 63965                        Scientific Conferences
# 63966           International short research visits
# 63967           International short research visits
# 63968           International short research visits
#
#                          Funding Instrument Hierarchy  \
# 0                                     Project funding
# 1                                     Project funding
# 2                                     Project funding
# 3                                     Project funding
# 4                                     Project funding
# 5                                     Project funding
# 6                                     Project funding
# 7                                     Project funding
# 8                                     Project funding
# 9                                     Project funding
# 10                                    Project funding
# 11                                    Project funding
# 12                                    Project funding
# 13                                    Project funding
# 14                                    Project funding
# 15                                    Project funding
# 16                                    Project funding
# 17                                    Project funding
# 18                                    Project funding
# 19                                    Project funding
# 20                                    Project funding
# 21                                    Project funding
# 22                                    Project funding
# 23                                    Project funding
# 24                                    Project funding
# 25                                    Project funding
# 26                                    Project funding
# 27                                    Project funding
# 28                                    Project funding
# 29                                    Project funding
# ...                                               ...
# 63939                           Science communication
# 63940                                         Careers
# 63941                                         Careers
# 63942                                         Careers
# 63943                                         Careers
# 63944                                         Careers
# 63945                                         Careers
# 63946                                         Careers
# 63947                                         Careers
# 63948                                         Careers
# 63949                                         Careers
# 63950                           Science communication
# 63951  Programmes;National Research Programmes (NRPs)
# 63952  Programmes;National Research Programmes (NRPs)
# 63953  Programmes;National Research Programmes (NRPs)
# 63954                                         Careers
# 63955                           Science communication
# 63956                                         Careers
# 63957                                         Careers
# 63958                           Science communication
# 63959                           Science communication
# 63960                                         Careers
# 63961                                         Careers
# 63962                                         Careers
# 63963                           Science communication
# 63964                           Science communication
# 63965                           Science communication
# 63966                                         Careers
# 63967                                         Careers
# 63968                                         Careers
#
#                                              Institution  \
# 0                                                    NaN
# 1      Faculté de Psychologie et des Sciences de l'Ed...
# 2      Kommission für das Corpus philosophorum medii ...
# 3      Abt. Handschriften und Alte Drucke Bibliothek ...
# 4                           Schweiz. Thesauruskommission
# 5      Séminaire de politique économique, d'économie ...
# 6      Institut für ökumenische Studien Université de...
# 7              Ostasiatisches Seminar Universität Zürich
# 8                                                    NaN
# 9      Laboratoire de Didactique et Epistémologie des...
# 10     Klinische Psychologie und Psychotherapie Insti...
# 11     Schweizerische Rechtsquellen c/o Universität Z...
# 12     Département de Sociologie Faculté des Sciences...
# 13     Institut für Volkswirtschaft WWZ / FGS Univers...
# 14            Soziologisches Institut Universität Zürich
# 15                                 Forschungszentrum FAL
# 16     Faculté de Psychologie et des Sciences de l'Ed...
# 17            Soziologisches Institut Universität Zürich
# 18                                                   NaN
# 19                                                   NaN
# 20     Faculté de Psychologie et des Sciences de l'Ed...
# 21                                                   NaN
# 22     Forschungsbereich Politisches Verhalten und Oe...
# 23     Département des langues et des littératures fr...
# 24                                                   NaN
# 25                                                   NaN
# 26            Schweizerische Gesellschaft für Volkskunde
# 27                         Kuratorium Carl J. Burckhardt
# 28                                                   NaN
# 29     Eidg. Forschungsanstalt für Wald, Schnee und L...
# ...                                                  ...
# 63939  Institut Sozialmanagement und Sozialpolitik Ho...
# 63940                Stiftung Bibliothek Werner Oechslin
# 63941  School of Geographical Sciences University of ...
# 63942                                                NaN
# 63943              CSIRO Marine and Atmospheric Research
# 63944                                                NaN
# 63945     Departement Geographie, SIE Universität Zürich
# 63946  CReAM Department of Economics University Colle...
# 63947                                                NaN
# 63948                                              Eawag
# 63949                      Catholic University of Bukavu
# 63950  Fondation Jean Monnet pour l'Europe Centre de ...
# 63951  Planning of Landscape and Urban Systems Instit...
# 63952  Forschungsanstalt Agroscope Reckenholz-Tänikon...
# 63953  Forschung und Beratung in Wirtschaft und Polit...
# 63954            Zoologisches Institut Universität Basel
# 63955  Zentrum für Religion, Wirtschaft und Politik T...
# 63956  Abteilung für Neuropsychologie Zentrum für Kog...
# 63957                                                NaN
# 63958         Abteilung für Indologie Universität Zürich
# 63959  Institut Religions, Cultures, Modernité FTSR U...
# 63960                                                NaN
# 63961  Department of Physics University of Massachusetts
# 63962                                                NaN
# 63963     Haute École d'art et de design - Genève HES-SO
# 63964  Departement Design Zürcher Hochschule der Küns...
# 63965  Institute Performing Arts and Film Zürcher Hoc...
# 63966  Department of Electrical Engineering and Compu...
# 63967  Département de Biologie Faculté des Sciences U...
# 63968  The Forsyth Institute Department of Microbiolo...
#
#                                               University  Discipline Number  \
# 0                                   Nicht zuteilbar - NA              10302
# 1                              Université de Genève - GE              10104
# 2                NPO (Biblioth., Museen, Verwalt.) - NPO              10101
# 3                                 Universität Basel - BS              10302
# 4                NPO (Biblioth., Museen, Verwalt.) - NPO              10303
# 5                            Université de Fribourg - FR              10203
# 6                            Université de Fribourg - FR              10102
# 7                                Universität Zürich - ZH              10301
# 8                            Université de Lausanne - LA              10502
# 9                              Université de Genève - GE              10105
# 10                           Université de Fribourg - FR              10105
# 11               NPO (Biblioth., Museen, Verwalt.) - NPO              10205
# 12                             Université de Genève - GE              10201
# 13                                Universität Basel - BS              10203
# 14                               Universität Zürich - ZH              10201
# 15                           Université de Fribourg - FR              10104
# 16                             Université de Genève - GE              10105
# 17                               Universität Zürich - ZH              10201
# 18                                  Nicht zuteilbar - NA              10201
# 19                           Université de Lausanne - LA              10201
# 20                             Université de Genève - GE              10104
# 21                                 Universität Bern - BE              10201
# 22                               Universität Zürich - ZH              10202
# 23                             Université de Genève - GE              10502
# 24                                  Nicht zuteilbar - NA              10302
# 25                                  Nicht zuteilbar - NA              10502
# 26               NPO (Biblioth., Museen, Verwalt.) - NPO              10403
# 27               NPO (Biblioth., Museen, Verwalt.) - NPO              10302
# 28                               Universität Zürich - ZH              10403
# 29     Eidg. Forschungsanstalt für Wald,Schnee,Land -...              10402
# ...                                                  ...                ...
# 63939                           Hochschule Luzern - HSLU              10202
# 63940                                                NaN              10407
# 63941                                                NaN              20705
# 63942                                                NaN              10105
# 63943                                                NaN              20704
# 63944                                                NaN              10406
# 63945                                                NaN              20702
# 63946                                                NaN              10203
# 63947                                                NaN              30103
# 63948                                                NaN              20511
# 63949                                                NaN              20701
# 63950            NPO (Biblioth., Museen, Verwalt.) - NPO              10202
# 63951                                  ETH Zürich - ETHZ              20511
# 63952                Forschungsanstalten Agroscope - AGS              20701
# 63953                       Firmen/Privatwirtschaft - FP              10202
# 63954                                                NaN              30202
# 63955                             Universität Basel - BS              10102
# 63956                                                NaN              30302
# 63957                                                NaN              20504
# 63958                            Universität Zürich - ZH              10503
# 63959                        Université de Lausanne - LA              10301
# 63960                                                NaN              20801
# 63961                                                NaN              20409
# 63962                                                NaN              10202
# 63963                 HES de Suisse occidentale - HES-SO              10603
# 63964             Zürcher Fachhochschule (ohne PH) - ZFH              10603
# 63965             Zürcher Fachhochschule (ohne PH) - ZFH              10604
# 63966                                                NaN              20511
# 63967                                                NaN              30102
# 63968                                                NaN              30307
#
#                                        Discipline Name  \
# 0                                        Swiss history
# 1                     Educational science and Pedagogy
# 2                                           Philosophy
# 3                                        Swiss history
# 4                Ancient history and Classical studies
# 5                                            Economics
# 6                         Religious sciences, Theology
# 7                                   History in general
# 8                     Romance languages and literature
# 9                                           Psychology
# 10                                          Psychology
# 11                                      Legal sciences
# 12                                           Sociology
# 13                                           Economics
# 14                                           Sociology
# 15                    Educational science and Pedagogy
# 16                                          Psychology
# 17                                           Sociology
# 18                                           Sociology
# 19                                           Sociology
# 20                    Educational science and Pedagogy
# 21                                           Sociology
# 22                                   Political science
# 23                    Romance languages and literature
# 24                                       Swiss history
# 25                    Romance languages and literature
# 26                                           Ethnology
# 27                                       Swiss history
# 28                                           Ethnology
# 29                                         Archaeology
# ...                                                ...
# 63939                                Political science
# 63940            Architecture and Social urban science
# 63941                 Hydrology, Limnology, Glaciology
# 63942                                       Psychology
# 63943  Climatology. Atmospherical Chemistry, Aeronomoy
# 63944                               Theater and Cinema
# 63945                                    Geomorphology
# 63946                                        Economics
# 63947                       Cellular Biology, Cytology
# 63948        Other disciplines of Engineering Sciences
# 63949                                         Pedology
# 63950                                Political science
# 63951        Other disciplines of Engineering Sciences
# 63952                                         Pedology
# 63953                                Political science
# 63954                                          Zoology
# 63955                     Religious sciences, Theology
# 63956               Neurophysiology and Brain Research
# 63957                           Electrical Engineering
# 63958                   Other languages and literature
# 63959                               History in general
# 63960                                          Geology
# 63961                     Other disciplines of Physics
# 63962                                Political science
# 63963                                             Arts
# 63964                                             Arts
# 63965                                   Music, Theatre
# 63966        Other disciplines of Engineering Sciences
# 63967                                Molecular Biology
# 63968                             Medical Microbiology
#
#                                Discipline Name Hierarchy  Start Date  \
# 0      Human and Social Sciences;Theology & religious...  01.10.1975
# 1      Human and Social Sciences;Psychology, educatio...  01.10.1975
# 2      Human and Social Sciences;Linguistics and lite...  01.03.1976
# 3      Human and Social Sciences;Theology & religious...  01.10.1975
# 4      Human and Social Sciences;Theology & religious...  01.01.1976
# 5               Human and Social Sciences;Economics, law  01.01.1976
# 6      Human and Social Sciences;Theology & religious...  01.01.1976
# 7      Human and Social Sciences;Theology & religious...  01.10.1975
# 8      Human and Social Sciences;Linguistics and lite...  01.10.1975
# 9      Human and Social Sciences;Psychology, educatio...  01.10.1975
# 10     Human and Social Sciences;Psychology, educatio...  01.10.1975
# 11              Human and Social Sciences;Economics, law  01.10.1975
# 12     Human and Social Sciences;Sociology, social wo...  01.10.1975
# 13              Human and Social Sciences;Economics, law  01.10.1975
# 14     Human and Social Sciences;Sociology, social wo...  01.10.1975
# 15     Human and Social Sciences;Psychology, educatio...  01.10.1975
# 16     Human and Social Sciences;Psychology, educatio...  01.10.1975
# 17     Human and Social Sciences;Sociology, social wo...  01.01.1976
# 18     Human and Social Sciences;Sociology, social wo...  01.01.1976
# 19     Human and Social Sciences;Sociology, social wo...  01.12.1975
# 20     Human and Social Sciences;Psychology, educatio...  01.10.1975
# 21     Human and Social Sciences;Sociology, social wo...  01.10.1975
# 22     Human and Social Sciences;Sociology, social wo...  01.01.1976
# 23     Human and Social Sciences;Linguistics and lite...  01.10.1975
# 24     Human and Social Sciences;Theology & religious...  01.01.1976
# 25     Human and Social Sciences;Linguistics and lite...  01.10.1975
# 26     Human and Social Sciences;Ethnology, social an...  01.10.1975
# 27     Human and Social Sciences;Theology & religious...  01.10.1975
# 28     Human and Social Sciences;Ethnology, social an...  01.10.1975
# 29     Human and Social Sciences;Theology & religious...  01.10.1975
# ...                                                  ...         ...
# 63939  Human and Social Sciences;Sociology, social wo...  01.08.2016
# 63940  Human and Social Sciences;Art studies, musicol...  01.07.2016
# 63941  Mathematics, Natural- and Engineering Sciences...  01.08.2016
# 63942  Human and Social Sciences;Psychology, educatio...  01.07.2016
# 63943  Mathematics, Natural- and Engineering Sciences...  01.08.2016
# 63944  Human and Social Sciences;Art studies, musicol...  01.07.2016
# 63945  Mathematics, Natural- and Engineering Sciences...  01.08.2016
# 63946           Human and Social Sciences;Economics, law  01.09.2016
# 63947     Biology and Medicine;Basic Biological Research  01.08.2016
# 63948  Mathematics, Natural- and Engineering Sciences...  01.09.2016
# 63949  Mathematics, Natural- and Engineering Sciences...  01.09.2016
# 63950  Human and Social Sciences;Sociology, social wo...  01.10.2016
# 63951  Mathematics, Natural- and Engineering Sciences...  01.10.2016
# 63952  Mathematics, Natural- and Engineering Sciences...  01.10.2016
# 63953  Human and Social Sciences;Sociology, social wo...  01.09.2016
# 63954               Biology and Medicine;General Biology  01.09.2016
# 63955  Human and Social Sciences;Theology & religious...  01.10.2016
# 63956        Biology and Medicine;Basic Medical Sciences  01.08.2016
# 63957  Mathematics, Natural- and Engineering Sciences...  01.08.2016
# 63958  Human and Social Sciences;Linguistics and lite...  01.10.2016
# 63959  Human and Social Sciences;Theology & religious...  01.10.2016
# 63960  Mathematics, Natural- and Engineering Sciences...  01.10.2016
# 63961  Mathematics, Natural- and Engineering Sciences...  01.10.2016
# 63962  Human and Social Sciences;Sociology, social wo...  01.09.2016
# 63963  Human and Social Sciences;Art studies, musicol...  01.10.2016
# 63964  Human and Social Sciences;Art studies, musicol...  01.10.2016
# 63965  Human and Social Sciences;Art studies, musicol...  01.09.2016
# 63966  Mathematics, Natural- and Engineering Sciences...  01.09.2016
# 63967     Biology and Medicine;Basic Biological Research  01.09.2016
# 63968        Biology and Medicine;Basic Medical Sciences  01.10.2016
#
#          End Date Approved Amount  \
# 0      30.09.1976        11619.00
# 1      30.09.1976        41022.00
# 2      28.02.1985        79732.00
# 3      30.09.1976        52627.00
# 4      30.04.1978       120042.00
# 5      31.12.1978        53009.00
# 6      31.12.1976        25403.00
# 7      31.03.1977        47100.00
# 8      31.03.1977        25814.00
# 9      30.09.1978       360000.00
# 10     31.12.1978       153886.00
# 11     30.09.1978       862200.00
# 12     30.09.1977       116991.00
# 13     31.12.1978       112664.00
# 14     31.12.1975         5000.00
# 15     30.09.1977       204018.00
# 16     30.09.1977       149485.00
# 17     31.08.1977        83983.00
# 18     31.12.1976        38152.00
# 19     31.01.1977        14138.00
# 20     30.09.1978       164602.00
# 21     30.04.1978       147795.00
# 22     30.06.1977        24552.00
# 23     30.09.1978        44802.00
# 24     31.12.1979        56000.00
# 25     30.09.1977       152535.00
# 26     30.09.1976       225000.00
# 27     30.04.1978       179124.00
# 28     31.03.1976        20000.00
# 29     30.09.1978       445198.00
# ...           ...             ...
# 63939  31.07.2017         1898.00
# 63940  30.09.2016         9300.00
# 63941  31.10.2016         9500.00
# 63942  31.07.2016         4000.00
# 63943  31.10.2016        11000.00
# 63944  31.08.2016         7500.00
# 63945  30.09.2016         8000.00
# 63946  30.11.2016         9300.00
# 63947  30.09.2016         7000.00
# 63948  31.10.2016         6000.00
# 63949  30.09.2016         4500.00
# 63950  31.12.2016         2800.00
# 63951  30.09.2017        99952.00
# 63952  31.12.2017        98040.00
# 63953  28.02.2018       100000.00
# 63954  30.11.2016        10500.00
# 63955  31.12.2016        10030.00
# 63956  31.10.2016         7870.00
# 63957  31.08.2016         3150.00
# 63958  31.12.2016        10600.00
# 63959  31.12.2016         2515.00
# 63960  31.10.2016         3500.00
# 63961  31.10.2016         4000.00
# 63962  30.09.2016         3550.00
# 63963  31.12.2016         3000.00
# 63964  31.12.2016         1000.00
# 63965  30.11.2016         2000.00
# 63966  31.12.2016        10500.00
# 63967  30.11.2016         9500.00
# 63968  30.11.2016         7000.00
#
#                                                 Keywords
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 63939  Gleichstellungspolitik;Betriebliche Gleichstel...
# 63940  Architectural education;Manuscripts of lecture...
# 63941  sensitivity analysis;uncertainty propagation i...
# 63942  Educational psychology;Mathematics instruction...
# 63943  mass spectrometry;hydrofluoroolefines;ozone de...
# 63944  Weimar Cinema;transatlantic cross-cultural tra...
# 63945  Surface exposure dating;10Be;Erosion;Modelling...
# 63946  thick labor market;agglomoration economies;fre...
# 63947  immunotherapy;dendritic cells;microtubule disr...
# 63948  gravity-driven membrane filtration;membrane fo...
# 63949      nitrous oxide;stable isotopes;eddy covariance
# 63950  Union européenne;intégration européenne;intégr...
# 63951          Synthesis;Spatial Planning;Soil resources
# 63952  soil survey;cost benefit analysis;soil informa...
# 63953  food production;governance;spatial development...
# 63954    Genomics;temperature;local adaptation;antioxida
# 63955  Religion;Development;Global South;Sustainabili...
# 63956  complex mental processing;EEG;MEG;inter-indivi...
# 63957  Diffusion MRI;In-vivo fetal imaging;Mathematic...
# 63958  Asia and Europe;Posthumanism;environmentalism;...
# 63959  Histoire des savoirs;Histoire de l'érudition;H...
# 63960  rock avalanches ;numerical modelling;field stu...
# 63961  fluid interfaces;anisotropic colloids;Contact ...
# 63962            Social activists;environmental politics
# 63963  architecture d'intérieur;espace;architecture;t...
# 63964  Cultural Studies;Sociology;Design Research;Phi...
# 63965  Diagrammatologie;Klangfarbe;Tonsysteme;Farbe/T...
# 63966  brain-computer interfaces;transcranical direct...
# 63967  Circadian Oscialltor;Delayed differential equa...
# 63968  Bacterial growth interaction;Dolosigranulum pi...
#
# [63969 rows x 15 columns]

# %%
df
# Out:
#                                                     Total Amount Canton
# Institution
# AGGS Staatsarchiv                                      663264.00
# AGRIDEA                                                911248.00
# Aargauer Kantonsbibliothek                            5553504.00
# Aargauer Kantonsschule Baden                            12380.00     AG
# Abteilung Biochemie Biozentrum Universität Basel      1000122.00     BS
# Abteilung Geowissenschaften Naturhistorisches M...     230218.00     BS
# Abteilung Mikrobiologie Biozentrum Universität ...     188000.00     BS
# Abwasserverband Altenrhein                             180269.00     SG
# Addiction Info Suisse                                  504497.00
# Agrogen-Stiftung                                         4000.00
# Albrecht von Haller-Stiftung                            25000.00
# Alimentarium Musée de l'alimentation                   230089.00
# Alter Ego                                              229910.00
# Amt für Archäologie des Kantons Thurgau               1782331.00     TG
# Amt für Raumentwicklung Baudirektion Kanton Zürich     375813.00     ZH
# Amt für Städtebau der Stadt Zürich Archäologie/...     293700.00
# Amt für Wasserwirtschaft                               365640.00
# Antikenmuseum                                          977384.00
# Appellationsgericht Basel-Stadt                        196830.00     BS
# Arbeitsgemeinschaft Swissaid / Fastenopfer / Br...      87550.00
# Arbeitsgemeinschaft zur Förderung des Futterbau...     235000.00
# Arbeitslehrerinnenseminar des Kantons Zürich            85000.00     ZH
# Arbeitsstelle der Stiftung für kulturwissenscha...      15860.00
# Arche Verlag AG                                        192273.00     AG
# Architektur, Holz und Bau Berner Fachhochschule       1257112.00
# Archiv für Agrargeschichte                             437096.00
# Archives D'Etat de Genève Etat de Genève               620680.00     GE
# Archives d'Etat de Genève                              862554.00     GE
# Archives de l'Etat de Fribourg                         106524.00     FR
# Archives de l'Etat de Neuchâtel                         15000.00     NE
# ...                                                          ...    ...
# Verein "Schweizerische Juristische Datenbank"          500366.00
# Verein Arbeitsstelle Schweiz des RISM                 2448763.00
# Verein Feministische Wissenschaft Schweiz                2400.00
# Verein NGL-SAA Neue Galerie Luzern - Swiss Acad...       9000.00
# Verein politikinitiativen Zürich c/o PIN                12000.00
# Vereinigung Walliser Museen (VWM)                       20000.00
# ViaStoria - Zentrum für Verkehrsgeschichte Kult...       1500.00
# Vindonissa Museum                                      136047.00
# Vitrocentre Romont                                      16230.73     FR
# Volkswirtschaftliches Institut Abteilung Oekono...     330992.00
# WDA Forum                                               10000.00
# WDA Forum AG                                             8500.00     AG
# WOHNSTADT Bau- und Verwaltungsgenossenschaft           119094.00
# Wasser- und Energiewirtschaftsamt des Kantons Bern    2080085.00     BE
# Webster University                                       3000.00     GE
# Wessenbergkommission                                   117162.00
# Wissenschaftliche Nationalpark- Kommission Inst...     875384.00
# Wissenschaftliche Nationalpark- Kommission Inst...     251252.00
# Wissensstadt Davos                                      25299.00     GR
# Zentral- & Hochschulbibliothek                         706485.00
# Zentralbibliothek Solothurn                            874401.00     SO
# Zentralbibliothek Zürich                              1445731.00     ZH
# Zentrum für Sprachstörungen                            182952.00
# Zwingliverein Schweiz. Landesmuseum                   1235385.00
# Zürcher Handelskammer Börsengebäude                    240000.00
# cfd - Migrationspolitik und Friedenspolitik              6700.00
# oikos foundation Institute for Economy and the ...      38000.00     SG
# swisstopo Bundesamt für Landestopographie               12000.00
# syndicom                                                14000.00
# École des Hautes Études Commerciales Université...     349500.00     VD
#
# [450 rows x 2 columns]

# %% [markdown]
# For our study we need only University Name and Approved Amount Columns

# %%
data = data[['University','Approved Amount']]
data.head(5)
# Out:
#                                 University Approved Amount
# 0                     Nicht zuteilbar - NA        11619.00
# 1                Université de Genève - GE        41022.00
# 2  NPO (Biblioth., Museen, Verwalt.) - NPO        79732.00
# 3                   Universität Basel - BS        52627.00
# 4  NPO (Biblioth., Museen, Verwalt.) - NPO       120042.00

# %% [markdown]
# The database description mentions that the University Field is left **empty** if the project is not carried out in Swiss University. Hence we decide to drop these entries as the money is not used by the Swiss University. There were **12981** such enteries.

# %%
null_data = data[data['University'].isnull()]
null_data.shape
# Out:
# (12981, 2)

# %%
clean_data = data.drop(data.index[null_data.index])
clean_data = clean_data.drop(clean_data.index[(clean_data['University'] ==  'Nicht zuteilbar - NA')])
clean_data = clean_data.drop(clean_data.index[(clean_data['University'] ==  'NPO (Biblioth., Museen, Verwalt.) - NPO')])

# %%
print("No. of Entries: {}".format(clean_data.shape[0]))
clean_data.head(10)
# Out:
# No. of Entries: 46920
#                      University Approved Amount
# 1     Université de Genève - GE        41022.00
# 3        Universität Basel - BS        52627.00
# 5   Université de Fribourg - FR        53009.00
# 6   Université de Fribourg - FR        25403.00
# 7       Universität Zürich - ZH        47100.00
# 8   Université de Lausanne - LA        25814.00
# 9     Université de Genève - GE       360000.00
# 10  Université de Fribourg - FR       153886.00
# 12    Université de Genève - GE       116991.00
# 13       Universität Basel - BS       112664.00

# %% [markdown]
# Removing the entry which don't have numeric value for amount column

# %%
clean_data = clean_data.drop(clean_data.index[clean_data['Approved Amount'] == 'data not included in P3'])
clean_data.shape
# Out:
# (46810, 5)

# %% [markdown]
# We identify different universities in our data and query for the geocoding data.

# %%
dictionary = clean_data.groupby('University').groups
university = list(dictionary.keys())
print("No. of unique universities:",len(university))
# Out:
# No. of unique universities: 75

# %%
clean_data1 = pd.DataFrame(clean_data.groupby('University')
                                    .apply(lambda x: x['Approved Amount'].astype(float).sum()))
#clean_data1.reset_index(level=0, inplace=True)
clean_data1.columns = ['Total Amount']
clean_data1
# Out:
#                                                     Total Amount
# University
# AO Research Institute - AORI                        3.435621e+06
# Allergie- und Asthmaforschung - SIAF                1.916996e+07
# Berner Fachhochschule - BFH                         3.102870e+07
# Biotechnologie Institut Thurgau - BITG              2.492535e+06
# Centre de rech. sur l'environnement alpin - CREALP  1.567678e+06
# EPF Lausanne - EPFL                                 1.175316e+09
# ETH Zürich - ETHZ                                   1.635597e+09
# Eidg. Anstalt für Wasserversorgung - EAWAG          7.461922e+07
# Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL  4.836039e+07
# Eidg. Hochschulinstitut für Berufsbildung - EHB     2.086572e+06
# Eidg. Material und Prüfungsanstalt - EMPA           5.857452e+07
# Ente Ospedaliero Cantonale - EOC                    5.067172e+06
# Fachhochschule Kalaidos - FHKD                      1.090280e+06
# Fachhochschule Nordwestschweiz (ohne PH) - FHNW     4.277191e+07
# Fachhochschule Ostschweiz - FHO                     4.437056e+06
# Facoltà di Teologia di Lugano - FTL                 8.000000e+03
# Fernfachhochschule Schweiz (Mitglied SUPSI) - FFHS  1.200000e+04
# Firmen/Privatwirtschaft - FP                        1.116867e+08
# Forschungsanstalten Agroscope - AGS                 3.311572e+07
# Forschungsinstitut für Opthalmologie - IRO          3.478469e+06
# Forschungsinstitut für biologischen Landbau - FIBL  7.442410e+06
# Forschungskommission SAGW                           1.000000e+05
# Franklin University Switzerland - FUS               6.595600e+04
# Friedrich Miescher Institute - FMI                  4.022914e+07
# HES de Suisse occidentale - HES-SO                  3.416297e+07
# Haute école pédagogique BE, JU, NE - HEPBEJUNE      6.273800e+05
# Haute école pédagogique du canton de Vaud - HEPL    1.430686e+06
# Haute école pédagogique fribourgeoise - HEPFR       1.547498e+06
# Hochschule Luzern - HSLU                            1.076812e+07
# Idiap Research Institute - IDIAP                    2.218311e+07
# ...                                                          ...
# Pädagogische Hochschule Nordwestschweiz - PHFHNW    3.476142e+06
# Pädagogische Hochschule Schaffhausen - PHSH         1.766910e+05
# Pädagogische Hochschule Schwyz - PHSZ               9.365510e+05
# Pädagogische Hochschule St. Gallen - PHSG           2.098387e+06
# Pädagogische Hochschule Thurgau - PHTG              1.526446e+06
# Pädagogische Hochschule Wallis - PHVS               4.254980e+05
# Pädagogische Hochschule Zug - PHZG                  4.957150e+05
# Pädagogische Hochschule Zürich - PHZFH              3.298346e+06
# Robert Walser-Stiftung Bern - RWS                   5.695790e+05
# SUP della Svizzera italiana - SUPSI                 2.404008e+07
# Schweiz. Hochschule für Logopädie Rorschach - SHLR  4.296000e+05
# Schweiz. Institut für Kunstwissenschaft - SIK-ISEA  4.649550e+06
# Schweizer Kompetenzzentrum Sozialwissensch. - FORS  3.473582e+07
# Schweizer Paraplegiker Forschung - SPF              1.944211e+06
# Staatsunabh. Theologische Hochschule Basel - STHB   1.730000e+04
# Swiss Center for Electronics and Microtech. - CSEM  1.806825e+07
# Swiss Institute of Bioinformatics - SIB             1.158322e+07
# Università della Svizzera italiana - USI            8.497055e+07
# Universität Basel - BS                              1.352251e+09
# Universität Bern - BE                               1.519373e+09
# Universität Luzern - LU                             3.998168e+07
# Universität St. Gallen - SG                         6.919495e+07
# Universität Zürich - ZH                             1.826843e+09
# Université de Fribourg - FR                         4.575262e+08
# Université de Genève - GE                           1.838237e+09
# Université de Lausanne - LA                         1.183291e+09
# Université de Neuchâtel - NE                        3.832046e+08
# Weitere Institute - FINST                           9.256736e+06
# Weitere Spitäler - ASPIT                            1.074981e+07
# Zürcher Fachhochschule (ohne PH) - ZFH              4.484345e+07
#
# [75 rows x 1 columns]

# %% [markdown]
# Add column for Geocoding data

# %%
clean_data1['Canton'] = ''
clean_data1['Latitude'] = '' 
clean_data1['Longitude'] = ''

clean_data1.head()
# Out:
#                                                     Total Amount Canton  \
# University
# AO Research Institute - AORI                           3435621.0
# Allergie- und Asthmaforschung - SIAF                  19169965.0
# Berner Fachhochschule - BFH                           31028695.0
# Biotechnologie Institut Thurgau - BITG                 2492535.0
# Centre de rech. sur l'environnement alpin - CREALP     1567678.0
#
#                                                    Latitude Longitude
# University
# AO Research Institute - AORI
# Allergie- und Asthmaforschung - SIAF
# Berner Fachhochschule - BFH
# Biotechnologie Institut Thurgau - BITG
# Centre de rech. sur l'environnement alpin - CREALP

# %% [markdown]
# Using Geonames Full Text Search API to map the universities to their respective columns. 'requests' library is used to get the HTTP response. But since 'University' names have spaces and other special characters, it needs to be UTF-8 encoded before using the requests.get. This is accomplished using 'parse.quote' method in 'urllib' library.

# %%
base_url = 'http://api.geonames.org/search?q='
url_end  = '&maxRows=2&username=ada_homework&type=json'
for uni in clean_data1.index:
    uni_tmp = uni
    if uni_tmp.find('-') != -1:
        uni_tmp = uni_tmp.replace(uni_tmp[uni_tmp.find('-'):],'')
    if uni_tmp.find('(') != -1:
        uni_tmp = uni_tmp.replace(uni_tmp[uni_tmp.find('('):],'')
        
    url = base_url + uni_tmp + url_end
    ## Encode special characters and spaces
    query = parse.quote(url,safe=':/&=?')
    ## Parse JSON data
    response = json.loads(requests.get(query).text)
    if bool(response['geonames']):
        clean_data1['Canton'].loc[uni]    = response['geonames'][0]['adminCode1']
        clean_data1['Latitude'].loc[uni]  = response['geonames'][0]['lat']
        clean_data1['Longitude'].loc[uni] = response['geonames'][0]['lng']
# Out:
# /Users/vidit/anaconda3/envs/python35/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
clean_data1
# Out:
#                                                     Total Amount Canton  \
# University
# AO Research Institute - AORI                        3.435621e+06     38
# Allergie- und Asthmaforschung - SIAF                1.916996e+07
# Berner Fachhochschule - BFH                         3.102870e+07
# Biotechnologie Institut Thurgau - BITG              2.492535e+06
# Centre de rech. sur l'environnement alpin - CREALP  1.567678e+06
# EPF Lausanne - EPFL                                 1.175316e+09
# ETH Zürich - ETHZ                                   1.635597e+09     ZH
# Eidg. Anstalt für Wasserversorgung - EAWAG          7.461922e+07
# Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL  4.836039e+07
# Eidg. Hochschulinstitut für Berufsbildung - EHB     2.086572e+06
# Eidg. Material und Prüfungsanstalt - EMPA           5.857452e+07
# Ente Ospedaliero Cantonale - EOC                    5.067172e+06
# Fachhochschule Kalaidos - FHKD                      1.090280e+06
# Fachhochschule Nordwestschweiz (ohne PH) - FHNW     4.277191e+07     BL
# Fachhochschule Ostschweiz - FHO                     4.437056e+06
# Facoltà di Teologia di Lugano - FTL                 8.000000e+03
# Fernfachhochschule Schweiz (Mitglied SUPSI) - FFHS  1.200000e+04
# Firmen/Privatwirtschaft - FP                        1.116867e+08
# Forschungsanstalten Agroscope - AGS                 3.311572e+07
# Forschungsinstitut für Opthalmologie - IRO          3.478469e+06
# Forschungsinstitut für biologischen Landbau - FIBL  7.442410e+06
# Forschungskommission SAGW                           1.000000e+05
# Franklin University Switzerland - FUS               6.595600e+04
# Friedrich Miescher Institute - FMI                  4.022914e+07
# HES de Suisse occidentale - HES-SO                  3.416297e+07
# Haute école pédagogique BE, JU, NE - HEPBEJUNE      6.273800e+05
# Haute école pédagogique du canton de Vaud - HEPL    1.430686e+06
# Haute école pédagogique fribourgeoise - HEPFR       1.547498e+06
# Hochschule Luzern - HSLU                            1.076812e+07
# Idiap Research Institute - IDIAP                    2.218311e+07
# ...                                                          ...    ...
# Pädagogische Hochschule Nordwestschweiz - PHFHNW    3.476142e+06
# Pädagogische Hochschule Schaffhausen - PHSH         1.766910e+05
# Pädagogische Hochschule Schwyz - PHSZ               9.365510e+05
# Pädagogische Hochschule St. Gallen - PHSG           2.098387e+06
# Pädagogische Hochschule Thurgau - PHTG              1.526446e+06
# Pädagogische Hochschule Wallis - PHVS               4.254980e+05
# Pädagogische Hochschule Zug - PHZG                  4.957150e+05
# Pädagogische Hochschule Zürich - PHZFH              3.298346e+06
# Robert Walser-Stiftung Bern - RWS                   5.695790e+05
# SUP della Svizzera italiana - SUPSI                 2.404008e+07
# Schweiz. Hochschule für Logopädie Rorschach - SHLR  4.296000e+05
# Schweiz. Institut für Kunstwissenschaft - SIK-ISEA  4.649550e+06
# Schweizer Kompetenzzentrum Sozialwissensch. - FORS  3.473582e+07
# Schweizer Paraplegiker Forschung - SPF              1.944211e+06
# Staatsunabh. Theologische Hochschule Basel - STHB   1.730000e+04
# Swiss Center for Electronics and Microtech. - CSEM  1.806825e+07
# Swiss Institute of Bioinformatics - SIB             1.158322e+07
# Università della Svizzera italiana - USI            8.497055e+07
# Universität Basel - BS                              1.352251e+09     BS
# Universität Bern - BE                               1.519373e+09     BE
# Universität Luzern - LU                             3.998168e+07
# Universität St. Gallen - SG                         6.919495e+07
# Universität Zürich - ZH                             1.826843e+09     ZH
# Université de Fribourg - FR                         4.575262e+08     FR
# Université de Genève - GE                           1.838237e+09
# Université de Lausanne - LA                         1.183291e+09     VD
# Université de Neuchâtel - NE                        3.832046e+08     NE
# Weitere Institute - FINST                           9.256736e+06
# Weitere Spitäler - ASPIT                            1.074981e+07
# Zürcher Fachhochschule (ohne PH) - ZFH              4.484345e+07
#
#                                                     Latitude Longitude
# University
# AO Research Institute - AORI                           -19.2  17.58333
# Allergie- und Asthmaforschung - SIAF
# Berner Fachhochschule - BFH
# Biotechnologie Institut Thurgau - BITG
# Centre de rech. sur l'environnement alpin - CREALP
# EPF Lausanne - EPFL
# ETH Zürich - ETHZ                                    47.3763   8.54805
# Eidg. Anstalt für Wasserversorgung - EAWAG
# Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL
# Eidg. Hochschulinstitut für Berufsbildung - EHB
# Eidg. Material und Prüfungsanstalt - EMPA
# Ente Ospedaliero Cantonale - EOC
# Fachhochschule Kalaidos - FHKD
# Fachhochschule Nordwestschweiz (ohne PH) - FHNW     47.53378   7.63856
# Fachhochschule Ostschweiz - FHO
# Facoltà di Teologia di Lugano - FTL
# Fernfachhochschule Schweiz (Mitglied SUPSI) - FFHS
# Firmen/Privatwirtschaft - FP
# Forschungsanstalten Agroscope - AGS
# Forschungsinstitut für Opthalmologie - IRO
# Forschungsinstitut für biologischen Landbau - FIBL
# Forschungskommission SAGW
# Franklin University Switzerland - FUS
# Friedrich Miescher Institute - FMI
# HES de Suisse occidentale - HES-SO
# Haute école pédagogique BE, JU, NE - HEPBEJUNE
# Haute école pédagogique du canton de Vaud - HEPL
# Haute école pédagogique fribourgeoise - HEPFR
# Hochschule Luzern - HSLU
# Idiap Research Institute - IDIAP
# ...                                                      ...       ...
# Pädagogische Hochschule Nordwestschweiz - PHFHNW
# Pädagogische Hochschule Schaffhausen - PHSH
# Pädagogische Hochschule Schwyz - PHSZ
# Pädagogische Hochschule St. Gallen - PHSG
# Pädagogische Hochschule Thurgau - PHTG
# Pädagogische Hochschule Wallis - PHVS
# Pädagogische Hochschule Zug - PHZG
# Pädagogische Hochschule Zürich - PHZFH
# Robert Walser-Stiftung Bern - RWS
# SUP della Svizzera italiana - SUPSI
# Schweiz. Hochschule für Logopädie Rorschach - SHLR
# Schweiz. Institut für Kunstwissenschaft - SIK-ISEA
# Schweizer Kompetenzzentrum Sozialwissensch. - FORS
# Schweizer Paraplegiker Forschung - SPF
# Staatsunabh. Theologische Hochschule Basel - STHB
# Swiss Center for Electronics and Microtech. - CSEM
# Swiss Institute of Bioinformatics - SIB
# Università della Svizzera italiana - USI
# Universität Basel - BS                              47.55832   7.58403
# Universität Bern - BE                               46.95096   7.43548
# Universität Luzern - LU
# Universität St. Gallen - SG
# Universität Zürich - ZH                             47.37092   8.53434
# Université de Fribourg - FR                         46.80683   7.15317
# Université de Genève - GE
# Université de Lausanne - LA                         46.52376   6.58409
# Université de Neuchâtel - NE                        46.99385   6.93789
# Weitere Institute - FINST
# Weitere Spitäler - ASPIT
# Zürcher Fachhochschule (ohne PH) - ZFH
#
# [75 rows x 4 columns]

# %%
import geocoder

for uni in clean_data1.index:
    uni_tmp = uni
    if uni_tmp.find('-') != -1:
        uni_tmp = uni_tmp.replace(uni_tmp[uni_tmp.find('-'):],'')
    if uni_tmp.find('(') != -1:
        uni_tmp = uni_tmp.replace(uni_tmp[uni_tmp.find('('):],'')
        
    

    response = geocoder.google(uni_tmp,components="country:CH")
    json_out = response.json
    if 'state' in json_out.keys():
        clean_data1['Canton'].loc[uni]    = json_out['state']
        clean_data1['Latitude'].loc[uni]  = json_out['lat']
        clean_data1['Longitude'].loc[uni] = json_out['lng']
# Out:
# /Users/vidit/anaconda3/envs/python35/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
clean_data1
# Out:
#                                                     Total Amount Canton  \
# University
# AO Research Institute - AORI                        3.435621e+06     38
# Allergie- und Asthmaforschung - SIAF                1.916996e+07
# Berner Fachhochschule - BFH                         3.102870e+07
# Biotechnologie Institut Thurgau - BITG              2.492535e+06     TG
# Centre de rech. sur l'environnement alpin - CREALP  1.567678e+06
# EPF Lausanne - EPFL                                 1.175316e+09     VD
# ETH Zürich - ETHZ                                   1.635597e+09     ZH
# Eidg. Anstalt für Wasserversorgung - EAWAG          7.461922e+07
# Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL  4.836039e+07
# Eidg. Hochschulinstitut für Berufsbildung - EHB     2.086572e+06
# Eidg. Material und Prüfungsanstalt - EMPA           5.857452e+07
# Ente Ospedaliero Cantonale - EOC                    5.067172e+06
# Fachhochschule Kalaidos - FHKD                      1.090280e+06
# Fachhochschule Nordwestschweiz (ohne PH) - FHNW     4.277191e+07     BL
# Fachhochschule Ostschweiz - FHO                     4.437056e+06
# Facoltà di Teologia di Lugano - FTL                 8.000000e+03     TI
# Fernfachhochschule Schweiz (Mitglied SUPSI) - FFHS  1.200000e+04
# Firmen/Privatwirtschaft - FP                        1.116867e+08
# Forschungsanstalten Agroscope - AGS                 3.311572e+07
# Forschungsinstitut für Opthalmologie - IRO          3.478469e+06
# Forschungsinstitut für biologischen Landbau - FIBL  7.442410e+06
# Forschungskommission SAGW                           1.000000e+05
# Franklin University Switzerland - FUS               6.595600e+04
# Friedrich Miescher Institute - FMI                  4.022914e+07
# HES de Suisse occidentale - HES-SO                  3.416297e+07
# Haute école pédagogique BE, JU, NE - HEPBEJUNE      6.273800e+05     NE
# Haute école pédagogique du canton de Vaud - HEPL    1.430686e+06     VD
# Haute école pédagogique fribourgeoise - HEPFR       1.547498e+06
# Hochschule Luzern - HSLU                            1.076812e+07     LU
# Idiap Research Institute - IDIAP                    2.218311e+07
# ...                                                          ...    ...
# Pädagogische Hochschule Nordwestschweiz - PHFHNW    3.476142e+06
# Pädagogische Hochschule Schaffhausen - PHSH         1.766910e+05     SH
# Pädagogische Hochschule Schwyz - PHSZ               9.365510e+05     SZ
# Pädagogische Hochschule St. Gallen - PHSG           2.098387e+06     SG
# Pädagogische Hochschule Thurgau - PHTG              1.526446e+06     TG
# Pädagogische Hochschule Wallis - PHVS               4.254980e+05     VS
# Pädagogische Hochschule Zug - PHZG                  4.957150e+05     ZG
# Pädagogische Hochschule Zürich - PHZFH              3.298346e+06     ZH
# Robert Walser-Stiftung Bern - RWS                   5.695790e+05     ZH
# SUP della Svizzera italiana - SUPSI                 2.404008e+07
# Schweiz. Hochschule für Logopädie Rorschach - SHLR  4.296000e+05     SG
# Schweiz. Institut für Kunstwissenschaft - SIK-ISEA  4.649550e+06
# Schweizer Kompetenzzentrum Sozialwissensch. - FORS  3.473582e+07
# Schweizer Paraplegiker Forschung - SPF              1.944211e+06
# Staatsunabh. Theologische Hochschule Basel - STHB   1.730000e+04     BS
# Swiss Center for Electronics and Microtech. - CSEM  1.806825e+07
# Swiss Institute of Bioinformatics - SIB             1.158322e+07
# Università della Svizzera italiana - USI            8.497055e+07
# Universität Basel - BS                              1.352251e+09     BS
# Universität Bern - BE                               1.519373e+09     BE
# Universität Luzern - LU                             3.998168e+07     LU
# Universität St. Gallen - SG                         6.919495e+07     SG
# Universität Zürich - ZH                             1.826843e+09     ZH
# Université de Fribourg - FR                         4.575262e+08     FR
# Université de Genève - GE                           1.838237e+09     GE
# Université de Lausanne - LA                         1.183291e+09     VD
# Université de Neuchâtel - NE                        3.832046e+08     NE
# Weitere Institute - FINST                           9.256736e+06
# Weitere Spitäler - ASPIT                            1.074981e+07
# Zürcher Fachhochschule (ohne PH) - ZFH              4.484345e+07
#
#                                                     Latitude Longitude
# University
# AO Research Institute - AORI                           -19.2  17.58333
# Allergie- und Asthmaforschung - SIAF
# Berner Fachhochschule - BFH
# Biotechnologie Institut Thurgau - BITG               47.6038   9.05574
# Centre de rech. sur l'environnement alpin - CREALP
# EPF Lausanne - EPFL                                   46.519    6.5676
# ETH Zürich - ETHZ                                    47.3765   8.54809
# Eidg. Anstalt für Wasserversorgung - EAWAG
# Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL
# Eidg. Hochschulinstitut für Berufsbildung - EHB
# Eidg. Material und Prüfungsanstalt - EMPA
# Ente Ospedaliero Cantonale - EOC
# Fachhochschule Kalaidos - FHKD
# Fachhochschule Nordwestschweiz (ohne PH) - FHNW     47.53378   7.63856
# Fachhochschule Ostschweiz - FHO
# Facoltà di Teologia di Lugano - FTL                  46.0037   8.95105
# Fernfachhochschule Schweiz (Mitglied SUPSI) - FFHS
# Firmen/Privatwirtschaft - FP
# Forschungsanstalten Agroscope - AGS
# Forschungsinstitut für Opthalmologie - IRO
# Forschungsinstitut für biologischen Landbau - FIBL
# Forschungskommission SAGW
# Franklin University Switzerland - FUS
# Friedrich Miescher Institute - FMI
# HES de Suisse occidentale - HES-SO
# Haute école pédagogique BE, JU, NE - HEPBEJUNE       46.9752   6.77155
# Haute école pédagogique du canton de Vaud - HEPL     46.5613   6.53676
# Haute école pédagogique fribourgeoise - HEPFR
# Hochschule Luzern - HSLU                             47.0608   8.32208
# Idiap Research Institute - IDIAP
# ...                                                      ...       ...
# Pädagogische Hochschule Nordwestschweiz - PHFHNW
# Pädagogische Hochschule Schaffhausen - PHSH          47.6959   8.63805
# Pädagogische Hochschule Schwyz - PHSZ                47.0207   8.65299
# Pädagogische Hochschule St. Gallen - PHSG            47.4245   9.37672
# Pädagogische Hochschule Thurgau - PHTG               47.6038   9.05574
# Pädagogische Hochschule Wallis - PHVS                46.1905   7.54492
# Pädagogische Hochschule Zug - PHZG                   47.1662   8.51549
# Pädagogische Hochschule Zürich - PHZFH               47.3769   8.54169
# Robert Walser-Stiftung Bern - RWS                    47.2349   8.65357
# SUP della Svizzera italiana - SUPSI
# Schweiz. Hochschule für Logopädie Rorschach - SHLR   47.4789   9.49168
# Schweiz. Institut für Kunstwissenschaft - SIK-ISEA
# Schweizer Kompetenzzentrum Sozialwissensch. - FORS
# Schweizer Paraplegiker Forschung - SPF
# Staatsunabh. Theologische Hochschule Basel - STHB    47.5596   7.58858
# Swiss Center for Electronics and Microtech. - CSEM
# Swiss Institute of Bioinformatics - SIB
# Università della Svizzera italiana - USI
# Universität Basel - BS                               47.5607   7.58269
# Universität Bern - BE                                 46.948   7.44745
# Universität Luzern - LU                              47.0494   8.31254
# Universität St. Gallen - SG                          47.4435   9.38289
# Universität Zürich - ZH                              47.3816   8.54817
# Université de Fribourg - FR                          46.8045   7.15244
# Université de Genève - GE                            46.1938   6.15179
# Université de Lausanne - LA                          46.5211   6.58015
# Université de Neuchâtel - NE                        46.99385   6.93789
# Weitere Institute - FINST
# Weitere Spitäler - ASPIT
# Zürcher Fachhochschule (ohne PH) - ZFH
#
# [75 rows x 4 columns]

# %%
#df = clean_data1[clean_data1['Canton'] == '']
df.to_csv('missing_mappings.csv',sep=',',encoding = 'cp1252')

# %%
manually_mapped_data = pd.read_csv('missing_mappings.csv',sep=',',encoding = 'cp1252')
manually_mapped_data.index = manually_mapped_data.University
val =  clean_data1.index.isin(manually_mapped_data.index)
print(manually_mapped_data.index)
clean_data1.loc[val,'Canton'] = manually_mapped_data['Canton']
clean_data1
# Out:
# Index(['AO Research Institute - AORI', 'Allergie- und Asthmaforschung - SIAF',
#        'Berner Fachhochschule - BFH',
#        'Centre de rech. sur l'environnement alpin - CREALP',
#        'Eidg. Anstalt für Wasserversorgung - EAWAG',
#        'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#        'Eidg. Hochschulinstitut für Berufsbildung - EHB',
#        'Eidg. Material und Prufungsanstalt - EMPA',
#        'Ente Ospedaliero Cantonale - EOC', 'Fachhochschule Kalaidos - FHKD',
#        'Fachhochschule Ostschweiz - FHO',
#        'Fernfachhochschule Schweiz (Mitglied SUPSI) - FFHS',
#        'Firmen/Privatwirtschaft - FP', 'Forschungsanstalten Agroscope - AGS',
#        'Forschungsinstitut für Opthalmologie - IRO',
#        'Forschungsinstitut für biologischen Landbau - FIBL',
#        'Forschungskommission SAGW', 'Franklin University Switzerland - FUS',
#        'Friedrich Miescher Institute - FMI',
#        'HES de Suisse occidentale - HES-SO',
#        'Haute école pédagogique fribourgeoise - HEPFR',
#        'Idiap Research Institute - IDIAP',
#        'Inst. Suisse de Spéléologie et Karstologie - ISSKA',
#        'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#        'Inst. universit. romand de Santé au Travail - IST',
#        'Interkant. Hochschule fur Heilpädagogik ZH - HfH',
#        'Istituto Svizzero di Roma - ISR',
#        'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#        'Pädagogische Hochschule Nordwestschweiz - PHFHNW',
#        'SUP della Svizzera italiana - SUPSI',
#        'Schweiz. Institut fur Kunstwissenschaft - SIK-ISEA',
#        'Schweizer Kompetenzzentrum Sozialwissensch. - FORS',
#        'Schweizer Paraplegiker Forschung - SPF',
#        'Swiss Center for Electronics and Microtech. - CSEM',
#        'Swiss Institute of Bioinformatics - SIB',
#        'Università della Svizzera italiana - USI', 'Weitere Institute - FINST',
#        'Weitere Spitäler - ASPIT', 'Zürcher Fachhochschule (ohne PH) - ZFH'],
#       dtype='object', name='University')
#                                                     Total Amount Canton  \
# University
# AO Research Institute - AORI                        3.435621e+06     GR
# Allergie- und Asthmaforschung - SIAF                1.916996e+07     GR
# Berner Fachhochschule - BFH                         3.102870e+07     BE
# Biotechnologie Institut Thurgau - BITG              2.492535e+06     TG
# Centre de rech. sur l'environnement alpin - CREALP  1.567678e+06     VS
# EPF Lausanne - EPFL                                 1.175316e+09     VD
# ETH Zürich - ETHZ                                   1.635597e+09     ZH
# Eidg. Anstalt für Wasserversorgung - EAWAG          7.461922e+07     ZH
# Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL  4.836039e+07     ZH
# Eidg. Hochschulinstitut für Berufsbildung - EHB     2.086572e+06     BE
# Eidg. Material und Prüfungsanstalt - EMPA           5.857452e+07
# Ente Ospedaliero Cantonale - EOC                    5.067172e+06     TI
# Fachhochschule Kalaidos - FHKD                      1.090280e+06     ZH
# Fachhochschule Nordwestschweiz (ohne PH) - FHNW     4.277191e+07     BL
# Fachhochschule Ostschweiz - FHO                     4.437056e+06     SG
# Facoltà di Teologia di Lugano - FTL                 8.000000e+03     TI
# Fernfachhochschule Schweiz (Mitglied SUPSI) - FFHS  1.200000e+04     SG
# Firmen/Privatwirtschaft - FP                        1.116867e+08    NaN
# Forschungsanstalten Agroscope - AGS                 3.311572e+07     ZH
# Forschungsinstitut für Opthalmologie - IRO          3.478469e+06     VS
# Forschungsinstitut für biologischen Landbau - FIBL  7.442410e+06     AG
# Forschungskommission SAGW                           1.000000e+05     BE
# Franklin University Switzerland - FUS               6.595600e+04     TI
# Friedrich Miescher Institute - FMI                  4.022914e+07     BS
# HES de Suisse occidentale - HES-SO                  3.416297e+07     JU
# Haute école pédagogique BE, JU, NE - HEPBEJUNE      6.273800e+05     NE
# Haute école pédagogique du canton de Vaud - HEPL    1.430686e+06     VD
# Haute école pédagogique fribourgeoise - HEPFR       1.547498e+06     FR
# Hochschule Luzern - HSLU                            1.076812e+07     LU
# Idiap Research Institute - IDIAP                    2.218311e+07     LU
# ...                                                          ...    ...
# Pädagogische Hochschule Nordwestschweiz - PHFHNW    3.476142e+06     AG
# Pädagogische Hochschule Schaffhausen - PHSH         1.766910e+05     SH
# Pädagogische Hochschule Schwyz - PHSZ               9.365510e+05     SZ
# Pädagogische Hochschule St. Gallen - PHSG           2.098387e+06     SG
# Pädagogische Hochschule Thurgau - PHTG              1.526446e+06     TG
# Pädagogische Hochschule Wallis - PHVS               4.254980e+05     VS
# Pädagogische Hochschule Zug - PHZG                  4.957150e+05     ZG
# Pädagogische Hochschule Zürich - PHZFH              3.298346e+06     ZH
# Robert Walser-Stiftung Bern - RWS                   5.695790e+05     ZH
# SUP della Svizzera italiana - SUPSI                 2.404008e+07     TI
# Schweiz. Hochschule für Logopädie Rorschach - SHLR  4.296000e+05     SG
# Schweiz. Institut für Kunstwissenschaft - SIK-ISEA  4.649550e+06
# Schweizer Kompetenzzentrum Sozialwissensch. - FORS  3.473582e+07     VD
# Schweizer Paraplegiker Forschung - SPF              1.944211e+06     LU
# Staatsunabh. Theologische Hochschule Basel - STHB   1.730000e+04     BS
# Swiss Center for Electronics and Microtech. - CSEM  1.806825e+07     NE
# Swiss Institute of Bioinformatics - SIB             1.158322e+07     VD
# Università della Svizzera italiana - USI            8.497055e+07     TI
# Universität Basel - BS                              1.352251e+09     BS
# Universität Bern - BE                               1.519373e+09     BE
# Universität Luzern - LU                             3.998168e+07     LU
# Universität St. Gallen - SG                         6.919495e+07     SG
# Universität Zürich - ZH                             1.826843e+09     ZH
# Université de Fribourg - FR                         4.575262e+08     FR
# Université de Genève - GE                           1.838237e+09     GE
# Université de Lausanne - LA                         1.183291e+09     VD
# Université de Neuchâtel - NE                        3.832046e+08     NE
# Weitere Institute - FINST                           9.256736e+06    NaN
# Weitere Spitäler - ASPIT                            1.074981e+07    NaN
# Zürcher Fachhochschule (ohne PH) - ZFH              4.484345e+07     ZH
#
#                                                     Latitude Longitude
# University
# AO Research Institute - AORI                           -19.2  17.58333
# Allergie- und Asthmaforschung - SIAF
# Berner Fachhochschule - BFH
# Biotechnologie Institut Thurgau - BITG               47.6038   9.05574
# Centre de rech. sur l'environnement alpin - CREALP
# EPF Lausanne - EPFL                                   46.519    6.5676
# ETH Zürich - ETHZ                                    47.3765   8.54809
# Eidg. Anstalt für Wasserversorgung - EAWAG
# Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL
# Eidg. Hochschulinstitut für Berufsbildung - EHB
# Eidg. Material und Prüfungsanstalt - EMPA
# Ente Ospedaliero Cantonale - EOC
# Fachhochschule Kalaidos - FHKD
# Fachhochschule Nordwestschweiz (ohne PH) - FHNW     47.53378   7.63856
# Fachhochschule Ostschweiz - FHO
# Facoltà di Teologia di Lugano - FTL                  46.0037   8.95105
# Fernfachhochschule Schweiz (Mitglied SUPSI) - FFHS
# Firmen/Privatwirtschaft - FP
# Forschungsanstalten Agroscope - AGS
# Forschungsinstitut für Opthalmologie - IRO
# Forschungsinstitut für biologischen Landbau - FIBL
# Forschungskommission SAGW
# Franklin University Switzerland - FUS
# Friedrich Miescher Institute - FMI
# HES de Suisse occidentale - HES-SO
# Haute école pédagogique BE, JU, NE - HEPBEJUNE       46.9752   6.77155
# Haute école pédagogique du canton de Vaud - HEPL     46.5613   6.53676
# Haute école pédagogique fribourgeoise - HEPFR
# Hochschule Luzern - HSLU                             47.0608   8.32208
# Idiap Research Institute - IDIAP
# ...                                                      ...       ...
# Pädagogische Hochschule Nordwestschweiz - PHFHNW
# Pädagogische Hochschule Schaffhausen - PHSH          47.6959   8.63805
# Pädagogische Hochschule Schwyz - PHSZ                47.0207   8.65299
# Pädagogische Hochschule St. Gallen - PHSG            47.4245   9.37672
# Pädagogische Hochschule Thurgau - PHTG               47.6038   9.05574
# Pädagogische Hochschule Wallis - PHVS                46.1905   7.54492
# Pädagogische Hochschule Zug - PHZG                   47.1662   8.51549
# Pädagogische Hochschule Zürich - PHZFH               47.3769   8.54169
# Robert Walser-Stiftung Bern - RWS                    47.2349   8.65357
# SUP della Svizzera italiana - SUPSI
# Schweiz. Hochschule für Logopädie Rorschach - SHLR   47.4789   9.49168
# Schweiz. Institut für Kunstwissenschaft - SIK-ISEA
# Schweizer Kompetenzzentrum Sozialwissensch. - FORS
# Schweizer Paraplegiker Forschung - SPF
# Staatsunabh. Theologische Hochschule Basel - STHB    47.5596   7.58858
# Swiss Center for Electronics and Microtech. - CSEM
# Swiss Institute of Bioinformatics - SIB
# Università della Svizzera italiana - USI
# Universität Basel - BS                               47.5607   7.58269
# Universität Bern - BE                                 46.948   7.44745
# Universität Luzern - LU                              47.0494   8.31254
# Universität St. Gallen - SG                          47.4435   9.38289
# Universität Zürich - ZH                              47.3816   8.54817
# Université de Fribourg - FR                          46.8045   7.15244
# Université de Genève - GE                            46.1938   6.15179
# Université de Lausanne - LA                          46.5211   6.58015
# Université de Neuchâtel - NE                        46.99385   6.93789
# Weitere Institute - FINST
# Weitere Spitäler - ASPIT
# Zürcher Fachhochschule (ohne PH) - ZFH
#
# [75 rows x 4 columns]

# %%
map_with_uni = folium.Map(location=[46.76, 8.26], tiles='Mapbox Bright',zoom_start=8)
for indx in range(clean_data1.shape[0]):
    if clean_data1.iloc[indx]['Latitude'] != '' and indx > 1 :
        folium.Marker(location=[clean_data1.iloc[indx]['Latitude'],clean_data1.iloc[indx]['Longitude']],
                      popup=clean_data1.index[indx]).add_to(map_with_uni)
map_with_uni
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
total_amt_per_canton = pd.DataFrame(clean_data1.groupby('Canton')
                                    .apply(lambda x: x['Total Amount'].astype(float).sum()))
total_amt_per_canton.reset_index(level=0,inplace=True)
total_amt_per_canton.columns = ['Canton','Total Amount']
total_amt_per_canton.drop(0, inplace= True)
total_amt_per_canton
# Out:
#    Canton  Total Amount
# 1      AG  1.261875e+08
# 2      BE  1.554579e+09
# 3      BL  4.277191e+07
# 4      BS  1.392498e+09
# 5      FR  4.590737e+08
# 6      GE  1.845120e+09
# 7      GR  3.653832e+07
# 8      JU  3.416297e+07
# 9      LU  7.685639e+07
# 10     NE  4.407644e+08
# 11     SG  9.120610e+07
# 12     SH  1.766910e+05
# 13     SZ  9.365510e+05
# 14     TG  4.018981e+06
# 15     TI  1.152623e+08
# 16     VD  2.406356e+09
# 17     VS  6.096464e+06
# 18     ZG  2.473055e+06
# 19     ZH  3.668336e+09

# %%
npo_data = data[data['University'] == 'NPO (Biblioth., Museen, Verwalt.) - NPO']
npo_data_ = pd.DataFrame(npo_data.groupby('Institution').apply(lambda x: x['Approved Amount'].astype(float).sum()))
npo_data_.columns = ['Total Amount']
npo_data_['Canton'] = ''

import geocoder
for indx in npo_data_.index :
    
    response = geocoder.google(indx,components="country:CH")
    json_out = response.json
    if 'state' in json_out.keys():
        npo_data_.loc[indx,'Canton'] = json_out['state']
# Out:
#                                                     Total Amount Canton
# Institution
# AGGS Staatsarchiv                                      663264.00
# AGRIDEA                                                911248.00
# Aargauer Kantonsbibliothek                            5553504.00
# Aargauer Kantonsschule Baden                            12380.00     AG
# Abteilung Biochemie Biozentrum Universität Basel      1000122.00     BS
# Abteilung Geowissenschaften Naturhistorisches M...     230218.00     BS
# Abteilung Mikrobiologie Biozentrum Universität ...     188000.00     BS
# Abwasserverband Altenrhein                             180269.00     SG
# Addiction Info Suisse                                  504497.00
# Agrogen-Stiftung                                         4000.00
# Albrecht von Haller-Stiftung                            25000.00
# Alimentarium Musée de l'alimentation                   230089.00
# Alter Ego                                              229910.00
# Amt für Archäologie des Kantons Thurgau               1782331.00
# Amt für Raumentwicklung Baudirektion Kanton Zürich     375813.00
# Amt für Städtebau der Stadt Zürich Archäologie/...     293700.00
# Amt für Wasserwirtschaft                               365640.00
# Antikenmuseum                                          977384.00
# Appellationsgericht Basel-Stadt                        196830.00
# Arbeitsgemeinschaft Swissaid / Fastenopfer / Br...      87550.00
# Arbeitsgemeinschaft zur Förderung des Futterbau...     235000.00
# Arbeitslehrerinnenseminar des Kantons Zürich            85000.00
# Arbeitsstelle der Stiftung für kulturwissenscha...      15860.00
# Arche Verlag AG                                        192273.00
# Architektur, Holz und Bau Berner Fachhochschule       1257112.00
# Archiv für Agrargeschichte                             437096.00
# Archives D'Etat de Genève Etat de Genève               620680.00     GE
# Archives d'Etat de Genève                              862554.00     GE
# Archives de l'Etat de Fribourg                         106524.00     FR
# Archives de l'Etat de Neuchâtel                         15000.00     NE
# ...                                                          ...    ...
# Verein "Schweizerische Juristische Datenbank"          500366.00
# Verein Arbeitsstelle Schweiz des RISM                 2448763.00
# Verein Feministische Wissenschaft Schweiz                2400.00
# Verein NGL-SAA Neue Galerie Luzern - Swiss Acad...       9000.00
# Verein politikinitiativen Zürich c/o PIN                12000.00
# Vereinigung Walliser Museen (VWM)                       20000.00
# ViaStoria - Zentrum für Verkehrsgeschichte Kult...       1500.00
# Vindonissa Museum                                      136047.00
# Vitrocentre Romont                                      16230.73
# Volkswirtschaftliches Institut Abteilung Oekono...     330992.00
# WDA Forum                                               10000.00
# WDA Forum AG                                             8500.00     AG
# WOHNSTADT Bau- und Verwaltungsgenossenschaft           119094.00
# Wasser- und Energiewirtschaftsamt des Kantons Bern    2080085.00     BE
# Webster University                                       3000.00     GE
# Wessenbergkommission                                   117162.00
# Wissenschaftliche Nationalpark- Kommission Inst...     875384.00
# Wissenschaftliche Nationalpark- Kommission Inst...     251252.00
# Wissensstadt Davos                                      25299.00     GR
# Zentral- & Hochschulbibliothek                         706485.00
# Zentralbibliothek Solothurn                            874401.00     SO
# Zentralbibliothek Zürich                              1445731.00     ZH
# Zentrum für Sprachstörungen                            182952.00
# Zwingliverein Schweiz. Landesmuseum                   1235385.00
# Zürcher Handelskammer Börsengebäude                    240000.00
# cfd - Migrationspolitik und Friedenspolitik              6700.00
# oikos foundation Institute for Economy and the ...      38000.00     SG
# swisstopo Bundesamt für Landestopographie               12000.00
# syndicom                                                14000.00
# École des Hautes Études Commerciales Université...     349500.00     VD
#
# [450 rows x 2 columns]

# %%
npo_cantons = pd.DataFrame(npo_data_.groupby('Canton').apply(lambda x: x['Total Amount'].sum()))
npo_cantons.columns = ['Total Amount']
npo_cantons.reset_index(level=0, inplace=True)
npo_cantons.drop(0)
# Out:
#    Canton  Total Amount
# 1      AG    1571015.00
# 2      BE   17976344.00
# 3      BL     257139.00
# 4      BS   14508915.00
# 5      FR    5484690.00
# 6      GE    4134301.00
# 7      GR   17874303.00
# 8      LU     329465.00
# 9      NE    1252757.00
# 10     SG    1937169.00
# 11     SH     764874.00
# 12     SO     874401.00
# 13     TG     394162.00
# 14     TI    2850906.00
# 15     UR     105000.00
# 16     VD   11851224.87
# 17     VS     293637.00
# 18     ZG      93200.00
# 19     ZH   14335653.00

# %%
list_of_cantons = ["ZH","BE","LU","UR", "SZ", "OW","NW", "GL", "ZG", "FR", "SO", "BS", "BL", "SH", "AR", "AI", "SG", "GR", "AG", "TG", "TI", "VD", "VS", "NE",
                   "GE", "JU"]
frame_of_cantons = pd.DataFrame(list_of_cantons, columns=['Canton'])
extended_data = pd.merge(frame_of_cantons, total_amt_per_canton, how='left', on="Canton")
extended_data = pd.merge(extended_data, npo_cantons, how='left', on="Canton")

# extended_data['Total Amount_x']
extended_data.fillna(0,inplace=True)
extended_data['Total Amount']= extended_data.apply(lambda x: x['Total Amount_x']+ x['Total Amount_y'],axis=1)

# %%
extended_data.drop(['Total Amount_x','Total Amount_y'],axis=1,inplace=True)
extended_data['Total Amount'] /= 1000000
extended_data.sort_values(by = 'Total Amount', ascending=False)
# Out:
#    Canton  Total Amount
# 0      ZH   3682.671935
# 21     VD   2418.207616
# 24     GE   1849.254339
# 1      BE   1572.555035
# 11     BS   1407.006822
# 9      FR    464.558358
# 23     NE    442.017197
# 18     AG    127.758536
# 20     TI    118.113226
# 16     SG     93.143271
# 2      LU     77.185857
# 17     GR     54.412619
# 12     BL     43.029053
# 25     JU     34.162965
# 22     VS      6.390101
# 19     TG      4.413143
# 8      ZG      2.566255
# 13     SH      0.941565
# 4      SZ      0.936551
# 10     SO      0.874401
# 3      UR      0.105000
# 14     AR      0.000000
# 15     AI      0.000000
# 7      GL      0.000000
# 6      NW      0.000000
# 5      OW      0.000000

# %%
state_geo = r'ch-cantons.topojson.json'
map2 = folium.Map(location=[46.76, 8.26], zoom_start=7, tiles='Mapbox Bright')
map2.choropleth(geo_path=state_geo, data=extended_data,
             columns=['Canton', 'Total Amount'],
             key_on='feature.id',threshold_scale=[0, 10, 100, 500, 1000, 5000],
             fill_color='YlGn', fill_opacity=0.7, line_opacity=0.2,topojson = 'objects.cantons',
             legend_name='Approved Amount')
map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>
